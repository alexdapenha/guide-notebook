# %% [markdown]
# <a href="https://colab.research.google.com/github/alexdapenha/guide-notebook/blob/main/Beginners_guide_jupyter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Beginner's Guide to Jupyte Notebook**

# %% [markdown]
# **Abstract:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Reading the Data**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1e8f1304-5d9b-442d-9ac7-b16dabd7363c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e8f1304-5d9b-442d-9ac7-b16dabd7363c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Controle Geral Proj Bahia - 3 CGEO - v.4.0 - Treino_Teste.xlsx to Controle Geral Proj Bahia - 3 CGEO - v.4.0 - Treino_Teste.xlsx

# %% [markdown]
# ## **Precessing the Data**

# %%
import pandas as pd
df = pd.read_excel('/content/Controle Geral Proj Bahia - 3 CGEO - v.4.0 - Treino_Teste.xlsx')
df.head()
# Out:
#           MI  ADM_Area_Pub_Civil_A  ...  EDICAO_t_Total  Tempo_Total_Execucao
# 0  1436-4-NE                   0.0  ...               8                    52
# 1  1436-4-SE                   0.0  ...               9                    53
# 2  1436-4-SO                   0.0  ...              10                    48
# 3  1509-2-SE                   0.0  ...               8                    44
# 4  1509-3-SE                   0.0  ...               4                    28
#
# [5 rows x 288 columns]

# %%
df.mean()
# Out:
# ADM_Area_Pub_Civil_A          0.005396
# ADM_Area_Pub_Militar_A        0.003597
# ADM_Edif_Pub_Civil_A          0.078237
# ADM_Edif_Pub_Civil_P          0.555755
# ADM_Edif_Pub_Militar_A        0.025180
#                                ...
# EDICAO_Qnt_dias               2.034142
# EDICAO_Rev_ANALO_Qnt_dias     1.803235
# EDICAO_Rev_DIGI_Qnt_dias      1.716083
# EDICAO_t_Total                5.553459
# Tempo_Total_Execucao         46.115004
# Length: 287, dtype: float64

# %% [markdown]
# ## **Visualizing the Data**

# %%
df.plot.scatter(x='Tempo_Total_Execucao', y='Geom_Total_MI')

# %%
import seaborn as sns
sns.lmplot(data=df, x='Tempo_Total_Execucao', y='Geom_Total_MI')

# %% [markdown]
# ## **Results**

# %% [markdown]
# ## **References**
